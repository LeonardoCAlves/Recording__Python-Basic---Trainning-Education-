# %% [markdown]
# <p style="text-align:left; font-size:1.8rem; color:#00ffb7">
# Operadores Aritméticos e lógicos:<br>
# +  Adição  <br>         *  Multiplicação<br>
# -  Subtração <br>       ** Exponenciação<br>
# /  Divisão<br>
# // Retorna o valor inteiro da divisão<br>
# %  Retorna o resto da divisão<br>
# >   Maior<br>           ==  Igual<br>
# <   Menor <br>          !=  Diferente<br>
# >=  Maior ou igual<br>
# <=  Menor ou igual<br>
# =   Atribuição<br>
# </p>
