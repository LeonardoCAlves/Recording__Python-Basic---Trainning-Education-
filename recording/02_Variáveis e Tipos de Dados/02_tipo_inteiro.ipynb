# %% [markdown]
# <p style="text-align:center; font-size:1.8rem; color:#00ffb7">
#     Número inteiro <strong>int</strong><br>
#     ex: 123 65 98 90
# </p>
# <p style="text-align:left; font-size:1.5rem; color:#fff">
# Dados númericos devem ser inserido sempres sem as aspas, exceto quando houver necessidade de manipulação destes valores como string.
# <p>
